# %%
from pydogpack.mesh import mesh
import numpy as np

# %% [markdown]
# # Mesh

# %% [markdown]
# ## One Dimensional Meshes

# %% [markdown]
# ### Uniform Mesh

# %%
mesh_1d_uniform = mesh.Mesh1DUniform(0.0, 1.0, 10)
mesh_1d_uniform.create_plot();

# %% [markdown]
# ### Custom Mesh

# %%
vertices = np.array([[-1.0], [-0.5], [-0.2], [0.0], [0.3], [0.7], [1.0]])
mesh_1d = mesh.Mesh1D(vertices)
mesh_1d.create_plot();

# %% [markdown]
# ## Two Dimensional Meshes

# %% [markdown]
# ### Cartesian Rectangle

# %%
mesh_2d_cartesian = mesh.Mesh2DCartesian(0.0, 1.0, 0.0, 1.0, 10, 10)
mesh_2d_cartesian.create_plot();

# %% [markdown]
# ### Triangulated Rectangle

# %%
mesh_2d_triangulated_rectangle = mesh.Mesh2DTriangulatedRectangle(0.0, 1.0, 0.0, 1.0, 10, 10)
mesh_2d_triangulated_rectangle.create_plot();

# %% [markdown]
# ### DogPack Generated

# %% [markdown]
# #### Circle

# %%
mesh_2d_meshgen_dogpack_circle = mesh.Mesh2DMeshGenDogPack("circle_sample_mesh")
mesh_2d_meshgen_dogpack_circle.create_plot();

# %% [markdown]
# #### Square

# %%
mesh_2d_meshgen_dogpack_square = mesh.Mesh2DMeshGenDogPack("square_sample_mesh")
mesh_2d_meshgen_dogpack_square.create_plot();

# %% [markdown]
# #### Star

# %%
mesh_2d_meshgen_dogpack_star = mesh.Mesh2DMeshGenDogPack("star_sample_mesh")
mesh_2d_meshgen_dogpack_star.create_plot();
